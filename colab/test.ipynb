# %%
print('Hello')

# %% [markdown]
# 연습

# %%
a = 2

# %%
print(a)

# %% [markdown]
# # 새 섹션

# %%
print(a)

# %%
for i in range(10 ,2 , -1) :
    print(i , "hello world")

# %%
a = 10;
def test(a) :
    if a ==1 :
        print(1)
    elif a==2 :
        print(2)
    else :
        print(3)

test(a)

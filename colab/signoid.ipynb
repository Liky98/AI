# %%
import numpy as np


def sigmoid(x):
    return 1 / (1 + np.exp(-x))

print(sigmoid(0.7225))

# for i in range(50):
#     x = input()
#     print(sigmoid(x))

# %%
import numpy as np


def sigmoid(x):
    return 1 / (1 + np.exp(-x))

print(sigmoid(0.828))

# for i in range(50):
#     x = input()
#     print(sigmoid(x))
